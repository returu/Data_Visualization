# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## 部分字体设定：

# %% [markdown]
# #### 默认情况：

# %%
plt.text(0.1,0.8,r'$s(t) = A \sin(2 \omega t)$',fontsize=40)
plt.text(0.1,0.4,r'$s(t) = \mathcal {A} \mathrm{sin}(2 \mathtt {\omega} \mathit{t})$',fontsize=40) # 更改字体
plt.axis('off') # 隐藏边框
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# #### 更改字体：

# %%
plt.rcParams["mathtext.default"] = "regular" # 更改字体

# %%
plt.text(0.1,0.8,r'$s(t) = A \sin(2 \omega t)$',fontsize=40)
plt.text(0.1,0.4,r'$s(t) = \mathcal {A} \mathrm{sin}(2 \mathtt {\omega} \mathit{t})$',fontsize=40)
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# ## 整体字体设定：

# %%
plt.rcParams["mathtext.fontset"] = "dejavusans" # 更改字体（默认）
plt.text(0.1,0.4,r'$R \prod_{i=a}^\infty a_i \sin({2} \pi fx_i)$',fontsize=40)
plt.text(0.1,0.8,"dejavusans",fontsize=30,color="m")
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.rcParams["mathtext.fontset"] = "dejavuserif" # 更改字体
plt.text(0.1,0.4,r'$R \prod_{i=a}^\infty a_i \sin({2} \pi fx_i)$',fontsize=40)
plt.text(0.1,0.8,"dejavuserif",fontsize=30,color="m")
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.rcParams["mathtext.fontset"] = "cm" # 更改字体
plt.text(0.1,0.4,r'$R \prod_{i=a}^\infty a_i \sin({2} \pi fx_i)$',fontsize=40)
plt.text(0.1,0.8,"cm",fontsize=30,color="m")
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.rcParams["mathtext.fontset"] = "stix" # 更改字体
plt.text(0.1,0.4,r'$R \prod_{i=a}^\infty a_i \sin({2} \pi fx_i)$',fontsize=40)
plt.text(0.1,0.8,"stix",fontsize=30,color="m")
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.rcParams["mathtext.fontset"] = "stixsans" # 更改字体
plt.text(0.1,0.4,r'$R \prod_{i=a}^\infty a_i \sin({2} \pi fx_i)$',fontsize=40)
plt.text(0.1,0.8,"stixsans",fontsize=30,color="m")
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)
