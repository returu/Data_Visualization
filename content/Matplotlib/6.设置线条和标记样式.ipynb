# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## 1、线条样式：

# %%
x = [1,5]

plt.plot(x,[1,1] , '-' , label='solid')
plt.plot(x,[2,2] , '--' , label='dashed')
plt.plot(x,[3,3] , ls='dashdot' , label='dashdot')
plt.plot(x,[4,4] , ls='dotted' , label='dotted')

plt.legend()
plt.show()

# %% [markdown]
# ## 2、标记样式：

# %%
x = [1,2,3,4,5]

plt.plot(x,[1,1,1,1,1] , marker='.' ,markersize=20,markerfacecolor='r',markeredgecolor='k',markeredgewidth=2, label='点标记')
plt.plot(x,[2,2,2,2,2] , marker='v' ,ms=10,mfc='b',mec='k',mew=2, label='三角形向下标记')
plt.plot(x,[3,3,3,3,3] , marker='1' ,ms=10,mec='k',mew=2, label='tri_down标记')
plt.plot(x,[4,4,4,4,4] , marker='D' ,ms=10,mfc='y',mec='k',mew=2,  label='钻石记号笔')

plt.legend()
plt.show()

# %% [markdown]
# #### 通过代码显示全部标记样式：

# %%
font_style = dict(family='SimHei',color='k',size=12)
line_marker_style = dict(linestyle=':',linewidth=2,color='b',markersize=10)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1, 1, 1)

msNameList = ["'.'→点标记",
              "','→像素标记",
              "'o'→圆标记",
              "'v'→三角形向下标记",
              "'^'→三角形向上标记",
              "'<'→左三角形",
              "'>'→右三角形",
              "'1'→tri_down标记",
              "'2'→tri_up标记",
              "'3'→三左标记",
              "'4'→三右标记",
              "'s'→方形标记",
              "'p'→五角标记",
              "'*'→星星标记",
              "'+'→加号标记",
              "'D'→钻石记号笔",
              "'d'→Thin_diamond标记",
              "'x'→X标记",
              "'H'→八边形标记",
              "'h'→六边形标记",
              "'|'→竖线标记",
              "'_'→横线标记"
             ]

markerstyleList = ['.',',','o','v','^','<','>','1','2','3','4','s','p','*','+','D','d','x','H','h','|','_']

x = [ 5,  6,  7,  8,  9, 10]
y = [1, 1, 1, 1, 1, 1]


for i,ms in enumerate(markerstyleList):
    ax.text(0,i+0.5,msNameList[i] , **font_style)
    ax.plot(x,list(map(lambda x:x+i,y)),marker=ms , **line_marker_style)
    

ax.set_xlim(-1,11)
ax.set_ylim(0,24)
ax.set_xticks([])
ax.set_yticks([])

plt.show()

# %% [markdown]
# ## 3、格式字符串：

# %%
x = [1,5]

plt.plot(x,[1,1] , 'r--' , label='红色虚线') # 红色虚线
plt.plot(x,[2,2] , 'bs-.' , label='蓝色方块虚点线') # 蓝色方块虚点线
plt.plot(x,[3,3] , 'g^' , label='绿色三角形') # 绿色三角形
plt.plot(x,[4,4] , ls=':' , label='默认颜色点线') # 默认颜色点线

plt.legend()
plt.show()
