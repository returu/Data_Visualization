# %%
a = {
		'黑龙江': [127.9688, 45.368 , 10],
		'内蒙古': [110.3467, 41.4899 , 15],
		"吉林": [125.8154, 44.2584 , 18],
		"辽宁": [123.1238, 42.1216 , 20],
		"河北": [114.4995, 38.1006 , 50],
		"天津": [117.4219, 39.4189 , 80],
		"山西": [112.3352, 37.9413 , 40],
		"陕西": [109.1162, 34.2004 , 40],
		"甘肃": [103.5901, 36.3043 , 30],
		"宁夏": [106.3586, 38.1775 , 20],
		"青海": [101.4038, 36.8207 , 10],
		"新疆": [87.9236, 43.5883 , 15],
		"西藏": [91.11, 29.97 , 10],
		"四川": [103.9526, 30.7617 , 60],
		"重庆": [108.384366, 30.439702 , 70],
		"山东": [117.1582, 36.8701 , 90],
		"河南": [113.4668, 34.6234 , 85],
		"江苏": [118.8062, 31.9208 , 95],
		"安徽": [117.29, 32.0581 , 70],
		"湖北": [114.3896, 30.6628 , 75],
		"浙江": [119.5313, 29.8773 , 95],
		"福建": [119.4543, 25.9222 , 80],
		"江西": [116.0046, 28.6633 , 70],
		"湖南": [113.0823, 28.2568 , 80],
		"贵州": [106.6992, 26.7682 , 50],
		"云南": [102.9199, 25.4663 , 40],
		"广东": [113.12244, 23.009505 , 90],
		"广西": [108.479, 23.1152 , 50],
		"海南": [110.3893, 19.8516 , 50],
		'上海': [121.4648, 31.2891 , 100]
	}

# %%
a
# Out:
# {'黑龙江': [127.9688, 45.368, 10],
#  '内蒙古': [110.3467, 41.4899, 15],
#  '吉林': [125.8154, 44.2584, 18],
#  '辽宁': [123.1238, 42.1216, 20],
#  '河北': [114.4995, 38.1006, 50],
#  '天津': [117.4219, 39.4189, 80],
#  '山西': [112.3352, 37.9413, 40],
#  '陕西': [109.1162, 34.2004, 40],
#  '甘肃': [103.5901, 36.3043, 30],
#  '宁夏': [106.3586, 38.1775, 20],
#  '青海': [101.4038, 36.8207, 10],
#  '新疆': [87.9236, 43.5883, 15],
#  '西藏': [91.11, 29.97, 10],
#  '四川': [103.9526, 30.7617, 60],
#  '重庆': [108.384366, 30.439702, 70],
#  '山东': [117.1582, 36.8701, 90],
#  '河南': [113.4668, 34.6234, 85],
#  '江苏': [118.8062, 31.9208, 95],
#  '安徽': [117.29, 32.0581, 70],
#  '湖北': [114.3896, 30.6628, 75],
#  '浙江': [119.5313, 29.8773, 95],
#  '福建': [119.4543, 25.9222, 80],
#  '江西': [116.0046, 28.6633, 70],
#  '湖南': [113.0823, 28.2568, 80],
#  '贵州': [106.6992, 26.7682, 50],
#  '云南': [102.9199, 25.4663, 40],
#  '广东': [113.12244, 23.009505, 90],
#  '广西': [108.479, 23.1152, 50],
#  '海南': [110.3893, 19.8516, 50],
# ...

# %%
result = []
for i in a:
    result.append({"coords": [[116.4551, 40.2539],[a[i][0], a[i][1]]],"value": a[i][2]})

# %%
result
# Out:
# [{'coords': [[116.4551, 40.2539], [127.9688, 45.368]], 'value': 10},
#  {'coords': [[116.4551, 40.2539], [110.3467, 41.4899]], 'value': 15},
#  {'coords': [[116.4551, 40.2539], [125.8154, 44.2584]], 'value': 18},
#  {'coords': [[116.4551, 40.2539], [123.1238, 42.1216]], 'value': 20},
#  {'coords': [[116.4551, 40.2539], [114.4995, 38.1006]], 'value': 50},
#  {'coords': [[116.4551, 40.2539], [117.4219, 39.4189]], 'value': 80},
#  {'coords': [[116.4551, 40.2539], [112.3352, 37.9413]], 'value': 40},
#  {'coords': [[116.4551, 40.2539], [109.1162, 34.2004]], 'value': 40},
#  {'coords': [[116.4551, 40.2539], [103.5901, 36.3043]], 'value': 30},
#  {'coords': [[116.4551, 40.2539], [106.3586, 38.1775]], 'value': 20},
#  {'coords': [[116.4551, 40.2539], [101.4038, 36.8207]], 'value': 10},
#  {'coords': [[116.4551, 40.2539], [87.9236, 43.5883]], 'value': 15},
#  {'coords': [[116.4551, 40.2539], [91.11, 29.97]], 'value': 10},
# ...

# %%
import json
f = open('data.json',mode = 'w')
json.dump(result,f)
f.close()

# %%
result_2 = []
for i in a:
    result_2.append({"name": i,"value": a[i]})

# %%
result_2
# Out:
# [{'name': '黑龙江', 'value': [127.9688, 45.368, 10]},
#  {'name': '内蒙古', 'value': [110.3467, 41.4899, 15]},
#  {'name': '吉林', 'value': [125.8154, 44.2584, 18]},
#  {'name': '辽宁', 'value': [123.1238, 42.1216, 20]},
#  {'name': '河北', 'value': [114.4995, 38.1006, 50]},
#  {'name': '天津', 'value': [117.4219, 39.4189, 80]},
#  {'name': '山西', 'value': [112.3352, 37.9413, 40]},
#  {'name': '陕西', 'value': [109.1162, 34.2004, 40]},
#  {'name': '甘肃', 'value': [103.5901, 36.3043, 30]},
#  {'name': '宁夏', 'value': [106.3586, 38.1775, 20]},
#  {'name': '青海', 'value': [101.4038, 36.8207, 10]},
#  {'name': '新疆', 'value': [87.9236, 43.5883, 15]},
#  {'name': '西藏', 'value': [91.11, 29.97, 10]},
#  {'name': '四川', 'value': [103.9526, 30.7617, 60]},
#  {'name': '重庆', 'value': [108.384366, 30.439702, 70]},
#  {'name': '山东', 'value': [117.1582, 36.8701, 90]},
#  {'name': '河南', 'value': [113.4668, 34.6234, 85]},
#  {'name': '江苏', 'value': [118.8062, 31.9208, 95]},
# ...

# %%
import json
f = open('city_points.json',mode = 'w')
json.dump(result_2,f)
f.close()
